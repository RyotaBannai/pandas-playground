# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
"""
#####you can see what available
df = pd.DataFrame()
df.plot.<TAB>
"""
# Out:
# '\n#####you can see what available\ndf = pd.DataFrame()\ndf.plot.<TAB>\n'

# %%
np.random.seed(123456)

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum(); ts.head(10)
# Out:
# 2000-01-01    0.469112
# 2000-01-02    0.186249
# 2000-01-03   -1.322810
# 2000-01-04   -2.458442
# 2000-01-05   -1.246330
# 2000-01-06   -1.419545
# 2000-01-07   -1.300336
# 2000-01-08   -2.344572
# 2000-01-09   -3.206421
# 2000-01-10   -5.310990
# Freq: D, dtype: float64

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))

# %%
df = df.cumsum()

# %%
df.plot();

# %%
## ?figsize don't make any change 
plt.figure(figsize=(1,10));df.plot();

# %%
##change the ration after making plot
df.plot();plt.gcf().set_size_inches(10, 5);

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()
df3['A'] = pd.Series(list(range(len(df))))
df3.plot(x='A', y='B')

# %%
## series data with columns(A-D)
df.iloc[5].plot(kind='bar'); plt.axhline(0, color='k')

# %%
df3.plotti
# Out:
#   File "<ipython-input-47-aa41e65dec35>", line 2
#     df.plot.<TAB>
#             ^
# SyntaxError: invalid syntax

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2.head(5)
# Out:
#           a         b         c         d
# 0  0.391846  0.843205  0.718831  0.698961
# 1  0.430446  0.137806  0.032447  0.402278
# 2  0.686151  0.096568  0.019449  0.696849
# 3  0.695122  0.207642  0.520968  0.226024
# 4  0.812852  0.813370  0.033704  0.560697

# %%
df2.plot.bar();

# %%
##or stacking
df2.plot.bar(stacked=True);

# %%
## Bar Horizontally
df2.plot.barh(stacked=True,alpha=0.9);

# %%
df4 = pd.DataFrame({
    'a': np.random.randn(1000) + 1, 
    'b': np.random.randn(1000),
    #'c': np.random.randn(1000) - 1
}, 
    columns=['a', 'b', 'c'])
plt.figure();
df4.plot.hist(alpha=0.5)

# %%
## Histogram stacking, set bins more specification
df4.plot.hist(stacked=True, bins=20)

# %%
## Cumulative
df4['a'].plot.hist(orientation='vertical', cumulative=True, color='rebeccapurple', alpha=0.7)

# %%
##diff method = difference between 2 values (prior and current)
plt.figure(figsize=(4,2))
df['A'].diff().hist(color='rebeccapurple', alpha=0.7)

# %% [markdown]
# - [How to write Markdown](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet#links)
# - [How to change the figure size](https://stackoverflow.com/questions/332289/how-do-you-change-the-size-of-figures-drawn-with-matplotlib)

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(5, 3), dpi=80, facecolor='w', edgecolor='k')
df['A'].diff().hist(color='rebeccapurple', alpha=0.7)

# %%
df.diff().hist(color='m', alpha=0.5, bins=50, stacked=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11d665550>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d5e1898>]], dtype=object)

# %%
data = pd.Series(np.random.randn(1000))
data.hist(by=np.random.randint(0, 5, 1000), figsize=(6, 4))
##y= the number of data, around 50 at the most
##x= the range of random values from np.random.randn === 'data' is 'index'
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11d20b898>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d1b27f0>]], dtype=object)

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange',medians='DarkBlue', caps='Gray')
df.plot.box(color = color, sym='r+', notch=True)

# %%
df.plot.box(vert=False, positions=[1, 2, 5, 6, 7])

# %%
#or you can just use Boxplot() instead of plot.box()
df = pd.DataFrame(np.random.rand(10,5))
bp = df.boxplot(figsize=(5,3))

# %%
## pandas separate data by column
df = pd.DataFrame(np.random.rand(10,2), columns=['Col1', 'Col2'] )
df['X'] = pd.Series(['A','A','A','A','A','B','B','B','B','B'])
plt.figure();
bp = df.boxplot(by='X',figsize=(3,3))

# %%
##you can control which column you to use
## 'by' means 'groupby'
df = pd.DataFrame(np.random.rand(10,3), columns=['Col1', 'Col2', 'Col3'])
df['X'] = pd.Series(['A','A','A','A','A','B','B','B','B','B'])
df['Y'] = pd.Series(['A','B','A','B','A','B','A','B','A','B'])
bp = df.boxplot(column=['Col1','Col2'], by=['X','Y'])

# %%
np.random.seed(1234)
df_box = pd.DataFrame(np.random.randn(50, 2))
df_box['g'] = np.random.choice(['A', 'B'], size=50)
df_box.loc[df_box['g'] == 'B', 1] += 3
bp = df_box.boxplot(by='g')

# %%
bp = df_box.groupby('g').boxplot()

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.area();

# %%
df.plot.area(stacked=False);

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a', y='b', figsize=(5,3));

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkBlue', label='Group 1');
ax1 = df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax);
ax2 = df.plot.scatter(x='d', y='b', color='M', label='Group 3', ax=ax1, figsize=(5,3), s=df['b']*100);

# %%
df.plot.scatter(x='a', y='b', c='d', s=50);

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] + np.arange(1000)
df.plot.hexbin(x='a', y='b', gridsize=25)

# %%
df['z'] = np.random.uniform(0, 3, 1000)
df.plot.hexbin(x='a', y='b', C='z', reduce_C_function=np.max, gridsize=25)

# %%
series = pd.Series(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], name='series')
series.plot.pie(figsize=(3, 3))

# %%
series
# Out:
# a    2.846862
# b    2.766815
# c    0.137316
# d    2.814940
# Name: series, dtype: float64

# %%
df = pd.DataFrame(3 * np.random.rand(4, 2), index=['a', 'b', 'c', 'd'], columns=['x', 'y'])
df['y'].plot.pie(figsize=(3, 3))

# %%
df[['y','x']].plot.pie(subplots=True,figsize=(6, 3))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x120bedf98>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1201a6470>], dtype=object)

# %%
## fontsize, 
## color
## number rounding, 
## labels instead of a legend '
explode = (0, 0.1, 0, 0)
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
series.plot.pie(labels=['AA', 'BB', 'CC', 'DD'], shadow=True,explode=explode, colors=colors,
                autopct='%.1f', fontsize=10, figsize=(3, 3))

# %% [markdown]
# <p>
#     <a href="https://medium.com/@kvnamipara/a-better-visualisation-of-pie-charts-by-matplotlib-935b7667d77f"></a>
# </p>

# %%
series.plot.pie(labels=['AA', 'BB', 'CC', 'DD'], shadow=True,explode=explode, colors=colors,
                autopct='%.1f', fontsize=10, figsize=(3, 3),startangle=-30)

# %% [markdown]
# https://medium.com/@kvnamipara/a-better-visualisation-of-pie-charts-by-matplotlib-935b7667d77f

# %%
#use up 40% of space in below case
#values whose sum total is less than 1.0
series = pd.Series([0.1] * 4, index=['a', 'b', 'c', 'd'], name='series2')
series.plot.pie(figsize=(3, 3))

# %%
from pandas.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
matplotlib.style.use('ggplot')
scatter_matrix(df, alpha=0.1, figsize=(4, 4), diagonal='kde', color='m')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2ad7f470>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2af19ba8>]], dtype=object)

# %%
##kernel density estimation, smoothing 
ser = pd.Series(np.random.randn(1000))
ser.plot.kde(figsize=(4, 3))

# %%
from pandas.plotting import andrews_curves
from sklearn import datasets
data = iris = datasets.load_iris()
X = iris.data[:, :2]  # we only take the first two features.
y = iris.target
name = iris.target_names
ddf = pd.DataFrame(dict(labels = y)).apply(lambda x: name[x])
#ddf = pd.DataFrame(dict(labels = y)).apply(dict(zip(*(map(int, list('012')), name))), axis=1)
df = pd.DataFrame(X, columns=['f_1','f_2'])
df = df.join(ddf, how='outer')
andrews_curves(df, 'labels')

# %%
import io
import requests
url="https://raw.githubusercontent.com/pandas-dev/pandas/master/pandas/tests/data/iris.csv"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))
plt.figure()
andrews_curves(c, 'Name')
## using the attributes of samples as coefficients for Fourier series

# %% [markdown]
# https://en.wikipedia.org/wiki/Andrews_plot

# %%
##range -π~π

# %%
c.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# http://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA

x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.figure(2, figsize=(4, 3))
plt.clf()

# Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1, edgecolor='k')
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xticks(())
plt.yticks(())

# To getter a better understanding of interaction of the dimensions
# plot the first three PCA dimensions
fig = plt.figure(1, figsize=(10, 8))
ax = Axes3D(fig, elev=-150, azim=110)
X_reduced = PCA(n_components=3).fit_transform(iris.data)
ax.scatter(X_reduced[:, 0], X_reduced[:, 1], X_reduced[:, 2], c=y,
           cmap=plt.cm.Set1, edgecolor='k', s=40)

ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("2nd eigenvector")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("3rd eigenvector")
ax.w_zaxis.set_ticklabels([])
plt.show()

# %%
from pandas.plotting import radviz
fig = plt.figure(figsize=(5,3))
radviz(c, 'Name')

# %%
##parallel_cordinates
fig = plt.figure(figsize=(5,3))
from pandas.plotting import parallel_coordinates
parallel_coordinates(c, 'Name')

# %%
from pandas.plotting import lag_plot
#data = pd.Series(0.1 * np.random.rand(1000) + 0.9 * np.sin(np.linspace(-99 * np.pi, 99 * np.pi, num=1000)))
data = pd.Series(np.random.rand(50))
lag_plot(data) #this shows data is random

# %%
# this is not random
data = pd.Series(0.1 * np.random.rand(1000) + 0.9 * np.sin(np.linspace(-99 * np.pi, 99 * np.pi, num=1000)))
lag_plot(data)

# %%
from pandas.plotting import autocorrelation_plot
data = pd.Series(np.random.rand(1000))
autocorrelation_plot(data)
##Autocorrelation plot. If random, the plot significantly close to zero
##datted dash is 98% confidence

# %%
##This is obviously non-random
data = pd.Series(0.7 * np.random.rand(1000) + 0.3 * np.sin(np.linspace(-9 * np.pi, 9 * np.pi, num=1000)))
autocorrelation_plot(data)

# %% [markdown]
# https://stackoverflow.com/questions/20637439/skip-rows-during-csv-import-pandas

# %%
url_fr ="https://www.itl.nist.gov/div898/handbook/datasets/FLICKER.DAT"
fr = requests.get(url_fr).content
d_fr = pd.read_csv(io.StringIO(fr.decode('utf-8')), header=10)
d_fr.columns = ['data']
autocorrelation_plot(d_fr)

# %% [markdown]
# https://www.itl.nist.gov/div898/handbook/eda/section3/autocopl.htm

# %%
#CO2 concentraton 
url_fr ="https://www.itl.nist.gov/div898/handbook/datasets/MLCO2MON.DAT"
fr = requests.get(url_fr).content
names = ['CO2','Year&Month', 'Year', 'Month']
d_fr = pd.read_csv(
    io.StringIO(fr.decode('utf-8')), 
    names = names, 
    skiprows=range(0, 25), 
    delim_whitespace=True, 
    header=None)
d_fr.tail()
# Out:
#         CO2  Year&Month  Year  Month
# 156  351.71     1987.38  1987      5
# 157  350.94     1987.46  1987      6
# 158  349.10     1987.54  1987      7
# 159  346.77     1987.63  1987      8
# 160  345.73     1987.71  1987      9

# %%
df = pd.DataFrame(d_fr); 
df = df[['CO2','Year', 'Month']]#WMO X85 mole fraction scale
df['Day'] = 1
df['date'] = pd.to_datetime(df[['Year', 'Month','Day']]); df= df.set_index('date');df
df.plot(y='CO2',figsize=(10,2), color='rebeccapurple')

# %%
#autocorrelation plot, random check-> fails : not random data
matplotlib.style.use('ggplot')
autocorrelation_plot(df['CO2'])

# %%
from pandas.plotting import bootstrap_plot
data = pd.Series(np.random.rand(1000))
bootstrap_plot(data, size=5, samples=500, color='grey')

# %%
matplotlib.style.use('default')
ts.plot(style='k--', label='Series',figsize=(4,3));

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = np.exp(ts.cumsum())
ts.plot(logy=True, figsize=(4,3))

# %%
## secondary axis
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))
df = df.cumsum()
df.A.plot()
df.B.plot(secondary_y=True, style='g',figsize=(4,3))

# %%
ax = df.plot(secondary_y=['A', 'B'],figsize=(4,3)) #need to use variable
ax.set_ylabel('CD scale')
ax.right_ax.set_ylabel('AB scale')
# Out:
# Text(0, 0.5, 'AB scale')

# %%
df.plot(secondary_y=['A', 'B'], mark_right=False, figsize=(4,3))

# %%
df.A.plot(x_compat=True,figsize=(4,2))

# %%
#if more than one data to combat x licks
with pd.plotting.plot_params.use('x_compat', True):
    df.A.plot(color='r', figsize=(4,2))
    df.B.plot(color='g', figsize=(4,2))
    df.C.plot(color='b', figsize=(4,2))

# %% [markdown]
# https://matplotlib.org/users/recipes.html#fixing-common-date-annoyances
# if the ticks are overrapping each other, check this out

# %%
##subplot
df.plot(subplots=True, figsize=(6, 6));

# %%
df.plot(subplots=True, layout=(2, 2), figsize=(4, 4), sharex=True);

# %%
df.plot(subplots=True, layout=(2, -1), figsize=(4, 4), sharex=True);

# %%
##multiple ploting
fig, axes = plt.subplots(4, 4, figsize=(6, 6));
plt.subplots_adjust(wspace=0.5, hspace=0.5);
target1 = [axes[0][0], axes[1][1], axes[2][2], axes[3][3]]
target2 = [axes[3][0], axes[2][1], axes[1][2], axes[0][3]]
df.plot(subplots=True, ax=target1, legend=False, sharex=False, sharey=False);
(-df).plot(subplots=True, ax=target2, legend=False, sharex=False, sharey=False);

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
df['A'].plot(ax=axes[0,0]); axes[0,0].set_title('A');
df['B'].plot(ax=axes[0,1]); axes[0,1].set_title('B');
df['C'].plot(ax=axes[1,0]); axes[1,0].set_title('C');
df['D'].plot(ax=axes[1,1]); axes[1,1].set_title('D');

# %%
ix3 = pd.MultiIndex.from_arrays([
    ['a', 'a', 'a', 'a', 'b', 'b', 'b', 'b'], ['foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar']], 
    names=['letter', 'word'])
df3 = pd.DataFrame({'data1': [3, 2, 4, 3, 2, 4, 3, 2], 'data2': [6, 5, 7, 5, 4, 5, 6, 5]}, index=ix3)
gp3 = df3.groupby(level=('letter', 'word'))
means = gp3.mean()
errors = gp3.std()
means
# Out:
#              data1  data2
# letter word
# a      bar     3.5    6.0
#        foo     2.5    5.5
# b      bar     2.5    5.5
#        foo     3.0    4.5

# %%
errors
# Out:
#                 data1     data2
# letter word
# a      bar   0.707107  1.414214
#        foo   0.707107  0.707107
# b      bar   0.707107  0.707107
#        foo   1.414214  0.707107

# %%
ci955
# Out:
#                 data1     data2
# letter word
# a      bar   1.414214  2.828427
#        foo   1.414214  1.414214
# b      bar   1.414214  1.414214
#        foo   2.828427  1.414214

# %%
fig, ax = plt.subplots()
means.plot.bar(yerr=errors, ax=ax, xerr=0.05, linestyle='-', figsize=(4,3))

# %%
ci955 =2*errors
fig, ax = plt.subplots()
plt.xticks(fontsize = 7)
means.plot.bar(yerr=ci955, ax=ax, xerr=0.05, linestyle='-', figsize=(4,3))

# %% [markdown]
# https://stackoverflow.com/questions/44603615/plot-95-confidence-interval-errorbar-python-pandas-dataframes

# %%
fig, ax = plt.subplots(1, 1)
df = pd.DataFrame(np.random.rand(5, 3), columns=['a', 'b', 'c'])
ax.get_xaxis().set_visible(False)   # Hide Ticks
df.plot(table=True, ax=ax, figsize=(6,2))

# %%
fig, ax = plt.subplots(1, 1)
ax.get_xaxis().set_visible(False)   # Hide Ticks
df.plot(table=np.round(df.T, 2), ax=ax, figsize=(6,2))

# %%
#add table where you want
from pandas.plotting import table
fig, ax = plt.subplots(1, 1)
table(ax, np.round(df.describe(), 2), loc='upper right', colWidths=[0.2, 0.2, 0.2])
df.plot(ax=ax, ylim=(0, 2), legend=None, figsize=(6,4))

# %% [markdown]
# https://matplotlib.org/api/axes_api.html#matplotlib.axes.Axes.table

# %%
# colormaps
df = pd.DataFrame(np.random.randn(1000, 10), index=ts.index)
df = df.cumsum()

# %%
plt.figure()
df.plot(colormap='cubehelix',figsize=(5,3))

# %%
#or you can pass mlp cm directly
from matplotlib import cm
plt.figure()
df.plot(colormap=cm.cubehelix, figsize=(5,3))

# %%
dd = pd.DataFrame(np.random.randn(10, 10)).applymap(abs)
dd = dd.cumsum()
plt.figure()
dd.plot.bar(colormap='Greens', figsize=(5,3))

# %%
#also parallel cordinate
fig = plt.figure(figsize=(5,2))
parallel_coordinates(c, 'Name', colormap='gist_rainbow')

# %%
fig = plt.figure(figsize=(5,2))
parallel_coordinates(c, 'Name', color=('#556270','#4ECDC4', '#C7F464'))

# %%
#andrews_curves
fig = plt.figure(figsize=(5,2))
andrews_curves(c, 'Name', colormap='winter')

# %%
price = pd.Series(np.random.randn(150).cumsum(), index=pd.date_range('2000-1-1', periods=150, freq='B'))
ma = price.rolling(20).mean()
mstd = price.rolling(20).std()
plt.figure(figsize=(7,3))
plt.plot(price.index, price, 'k')
plt.plot(ma.index, ma, 'b')
plt.fill_between(mstd.index, ma-2*mstd, ma+2*mstd, color='b', alpha=0.2)
